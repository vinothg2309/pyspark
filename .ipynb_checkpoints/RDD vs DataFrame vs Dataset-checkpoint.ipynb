# %% [markdown]
# # RDD vs DataFrame vs DataSet
#
# <img src="attachment:09cea82b-eeba-4a62-ae58-adcfbd1fe2b3.png" width=350 />
#
# <img src="attachment:e710a28e-05bf-4d88-819a-300db7eb774b.png" width=450 />

# %% [markdown]
# # Spark Interface API
#
# ![image.png](attachment:cf726a5c-395a-4428-bdbc-3bf34cd0f249.png)
